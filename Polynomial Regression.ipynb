# %% [markdown]
# # Polynomial Regression from scratch
# *This notebook was created on 27/08/2021*
# - Update Previous Linear Regression into Polynomial one.

# %% [markdown]
# ## Import Libaries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Model Definition

# %%
class MyRegressionModel:
    def __init__(self, dims, learning_rate=0.05, n_estimators=100, batch_size=-1):
        self.dims = dims
        self.params = self.initial_parameters(self.dims)
        self.learning_rate = learning_rate
        self.n_estimators = n_estimators
        self.batch_size = batch_size
    
    def initial_parameters(self, dims):
        np.random.seed(42)
        if type(dims) == int:
            dims = [dims]
        dims = dims + [1]
        params = {}
        for i in range(1, len(dims)):
            params['W'] = np.random.rand(dims[i], dims[i-1])
            params['b'] = np.zeros((dims[i], 1))
        return params
    
    def forward_propagation(self, X):
        params = self.params
        y_hat = np.dot(X, params['W'].T) + params['b']
        return y_hat
    
    def backward_propagation(self, X, y, y_hat):
        grads = {}
        m = X.shape[0]
        
        grads['dW'] = 2/m * np.dot((y_hat - y).T, X)
        grads['db'] = 2/m * np.sum(y_hat - y)
        return grads
    
    def update_params(self, grads):
        learning_rate=self.learning_rate
        params = self.params
        params['W'] = params['W'] - learning_rate*grads['dW']
        params['b'] = params['b'] - learning_rate*grads['db']
        return params
    
    def compute_cost(self, y, y_hat):
        m = y.shape[0]
        cost = 1/m * np.sum((y_hat - y)**2)
        return cost
    
    def fit(self, X, y, batch_size=-1):
        """
        Fit Linear Regression using Gradient Descent
        If - Model Batches size = -1 then Run Batch Gradient Descent
           - Model Batches size = 1  then Run Stochastic Gradient Descent
           - Model Batches size is some other numbers then run Mini-batch Gradient Descent
        Argument:
          -- X: A (m by n) numpy Array (or Matrix somehow) contains the input (features).
          -- y: A (m by 1) numpy Array contains the output (labels).
          -- m is the number of sample in the Trainning set, n is the number of features.
        """
        if (self.batch_size == -1):
            print('Fitting on Full Batch...')
            self.batch_fit(X, y)
        elif (self.batch_size == 1):
            print('Fitting using Stochastic Gradient Descent...')
            self.stochastic_fit(X, y)
        else:
            print('Fitting using Mini-Batch...')
            self.mini_batch_fit(X, y)
    
    def batch_fit(self, X, y):
        for i in range(self.n_estimators):
            y_hat = self.forward_propagation(X)
            curr_cost = self.compute_cost(y, y_hat)
            grads = self.backward_propagation(X, y, y_hat)
            
            self.params = self.update_params(grads)
            
            print('After {} estimators, Cost: {}'.format(i, curr_cost))
    
    def stochastic_fit(self, X, y):
        """
        Fit Linear Regression using Stochastic Gradient Descent (SGD)
        Argument:
          -- X: A (m by n) numpy Array (or Matrix somehow) contains the input (features).
          -- y: A (m by 1) numpy Array contains the output (labels).
          -- m is the number of sample in the Trainning set, n is the number of features.
        """
        for i in range(self.n_estimators):
            for j in range(X.shape[0]):
                X_curr, y_curr = X[j].reshape(1, X[j].shape[0]), y[j]
                y_hat = self.forward_propagation(X_curr)
                curr_cost = self.compute_cost(y_curr, y_hat)
                grads = self.backward_propagation(X_curr, y_curr, y_hat)
                self.params = self.update_params(grads)
                
                print('Epoch {}, After {} estimators, Cost: {}'.format(i, j, curr_cost))
                
    def mini_batch_fit(self, X, y):
        batches = self.mini_batch_split(X.shape[0], self.batch_size)
        for i in range(self.n_estimators):
            for j in range(len(batches)-1):
                batch_start = int(batches[j])
                batch_end = int(batches[j+1]) - 1

                X_curr, y_curr = X[batch_start:batch_end], y[batch_start: batch_end]
                y_hat = self.forward_propagation(X_curr)
                curr_cost = self.compute_cost(y_curr, y_hat)
                grads = self.backward_propagation(X_curr, y_curr, y_hat)
                self.params = self.update_params(grads)
                
                print('Epoch {}, After {} estimators, Cost: {}'.format(i, j, curr_cost))
                
                
    def mini_batch_split(self, m, batch_size=16):
        """
        Helper function, return the range of each mini-batch divided from batch size m
        """
        batches = np.linspace(0, (m // batch_size + 1) * batch_size, m // batch_size + 2)
        batches[-1] = m
        return batches
        
            
    def predict(self, X):
        return X * self.params['W'] + self.params['b']

# %% [markdown]
# ## Make an artificial Polynomial Dataset

# %%
np.random.seed(42)

# Define expected Function
m = 150
X = 6 * np.random.rand(m, 1) - 2
y = 0.5 * X**2 + 0.25*X + 2 + np.random.randn(m, 1)

# %%
plt.figure(figsize=(16, 6))
plt.plot(X, y, "b.")
plt.xlabel("$x_1$")
plt.ylabel("$y$", rotation=0)
# plt.axis([0, 2, 0, 15])
plt.show()

# %% [markdown]
# ## Create a New Model

# %%
linear_model = MyRegressionModel(X.shape[1])
linear_model.fit(X, y)
# Out:
# Fitting on Full Batch...
# After 0 estimators, Cost: 20.226588414464466
# After 1 estimators, Cost: 12.02324136522751
# After 2 estimators, Cost: 8.69269551734931
# After 3 estimators, Cost: 7.140273561095647
# After 4 estimators, Cost: 6.2691612390020515
# After 5 estimators, Cost: 5.685704823489273
# After 6 estimators, Cost: 5.244466416889731
# After 7 estimators, Cost: 4.888252151472548
# After 8 estimators, Cost: 4.591768610731744
# After 9 estimators, Cost: 4.3416991225038615
# After 10 estimators, Cost: 4.129591460483292
# After 11 estimators, Cost: 3.9492622008777745
# After 12 estimators, Cost: 3.7958019169827772
# After 13 estimators, Cost: 3.665154964382439
# After 14 estimators, Cost: 3.5539115853050545
# After 15 estimators, Cost: 3.459183534771859
# After 16 estimators, Cost: 3.378516663716633
# After 17 estimators, Cost: 3.30982297321904
# After 18 estimators, Cost: 3.2513250350469316
# After 19 estimators, Cost: 3.2015094627350247
# After 20 estimators, Cost: 3.1590875699814895
# After 21 estimators, Cost: 3.1229619670053848
# After 22 estimators, Cost: 3.0921981494125426
# After 23 estimators, Cost: 3.0660003160527562
# After 24 estimators, Cost: 3.0436907802873012
# After 25 estimators, Cost: 3.024692438552057
# After 26 estimators, Cost: 3.008513841474736
# After 27 estimators, Cost: 2.9947364809308903
# After 28 estimators, Cost: 2.9830039640274184
# After 29 estimators, Cost: 2.973012793912447
# After 30 estimators, Cost: 2.9645045189106622
# After 31 estimators, Cost: 2.957259046891227
# After 32 estimators, Cost: 2.951088951921982
# After 33 estimators, Cost: 2.945834625933602
# After 34 estimators, Cost: 2.9413601499766058
# After 35 estimators, Cost: 2.937549778268791
# After 36 estimators, Cost: 2.934304944082338
# After 37 estimators, Cost: 2.931541710018853
# After 38 estimators, Cost: 2.9291885967160263
# After 39 estimators, Cost: 2.927184733818884
# After 40 estimators, Cost: 2.9254782853849206
# After 41 estimators, Cost: 2.924025108991503
# After 42 estimators, Cost: 2.922787613859299
# After 43 estimators, Cost: 2.921733788453679
# After 44 estimators, Cost: 2.92083637241007
# After 45 estimators, Cost: 2.9200721513626053
# After 46 estimators, Cost: 2.919421356434715
# After 47 estimators, Cost: 2.9188671528576577
# After 48 estimators, Cost: 2.9183952044885784
# After 49 estimators, Cost: 2.917993302963042
# After 50 estimators, Cost: 2.9176510518889605
# After 51 estimators, Cost: 2.9173595979126326
# After 52 estimators, Cost: 2.9171114017001143
# After 53 estimators, Cost: 2.9169000429096643
# After 54 estimators, Cost: 2.9167200541102907
# After 55 estimators, Cost: 2.9165667793501955
# After 56 estimators, Cost: 2.916436253716579
# After 57 estimators, Cost: 2.916325100771237
# After 58 estimators, Cost: 2.916230445208835
# After 59 estimators, Cost: 2.9161498384784745
# After 60 estimators, Cost: 2.9160811954445696
# After 61 estimators, Cost: 2.9160227404485335
# After 62 estimators, Cost: 2.9159729613760303
# After 63 estimators, Cost: 2.915930570541588
# After 64 estimators, Cost: 2.9158944713787402
# After 65 estimators, Cost: 2.9158637300740353
# After 66 estimators, Cost: 2.9158375514111405
# After 67 estimators, Cost: 2.9158152582001806
# After 68 estimators, Cost: 2.9157962737601855
# After 69 estimators, Cost: 2.915780107001498
# After 70 estimators, Cost: 2.9157663397222677
# After 71 estimators, Cost: 2.9157546157903984
# After 72 estimators, Cost: 2.9157446319311195
# After 73 estimators, Cost: 2.9157361298818754
# After 74 estimators, Cost: 2.9157288897115823
# After 75 estimators, Cost: 2.9157227241314545
# After 76 estimators, Cost: 2.9157174736502114
# After 77 estimators, Cost: 2.9157130024483604
# After 78 estimators, Cost: 2.915709194864815
# After 79 estimators, Cost: 2.9157059524049695
# After 80 estimators, Cost: 2.9157031911928466
# After 81 estimators, Cost: 2.915700839801386
# After 82 estimators, Cost: 2.9156988374047748
# After 83 estimators, Cost: 2.9156971322049996
# After 84 estimators, Cost: 2.9156956800919382
# After 85 estimators, Cost: 2.9156944435023178
# After 86 estimators, Cost: 2.9156933904480278
# After 87 estimators, Cost: 2.91569249368865
# After 88 estimators, Cost: 2.915691730026806
# After 89 estimators, Cost: 2.9156910797080835
# After 90 estimators, Cost: 2.9156905259100343
# After 91 estimators, Cost: 2.915690054307003
# After 92 estimators, Cost: 2.915689652699561
# After 93 estimators, Cost: 2.915689310698922
# After 94 estimators, Cost: 2.915689019458212
# After 95 estimators, Cost: 2.915688771443611
# After 96 estimators, Cost: 2.9156885602394786
# After 97 estimators, Cost: 2.9156883803823823
# After 98 estimators, Cost: 2.915688227219778
# After 99 estimators, Cost: 2.915688096789654

# %% [markdown]
# ## Check the Model by Visualization
# - Plot the Dataset in Scatter Plot with a Model Linear Line

# %%
# Load Model's trained Parameters to plot it with the 
W = linear_model.params['W']
b = linear_model.params['b']
X_model = np.linspace(-5, 5, 100).reshape(100, 1) # use X_model to plot the line "naturally" :)

plt.figure(figsize=(20, 8))
plt.plot(X, y, "b.")
plt.plot(X_model, W*X_model + b, c="y", ls='-')


plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([-2, 4, -2, 15])
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# - The Linear Model Worked poorly here.
# - With this dataset, Polynomial Regression Model will shine.

# %% [markdown]
# # Build a Polynomial Regression Model
# - In order to build a Polynomial Model, we have to make Polynomial Features based on current features first.
# - Since we only have 1 feature, this process must be easy for us.

# %%
# Define a function for this task, why not?
def polynomial_features(features, degree=2):
    """
    Return a numpy matrix contains normal features (input) and the polynomial features with nth degree.
    """
    poly_features = np.concatenate((features, features ** degree), axis=1)
    
    return poly_features

# %%
# Create a new poly dataset based on the original dataset
X_poly = polynomial_features(X)

# %%
poly_model = MyRegressionModel(dims=X_poly.shape[1], n_estimators=10, batch_size=1, learning_rate=0.001)

poly_model.fit(X_poly, y)
# Out:
# Fitting using Stochastic Gradient Descent...
# Epoch 0, After 0 estimators, Cost: 3.060037883625356
# Epoch 0, After 1 estimators, Cost: 18.957349281767435
# Epoch 0, After 2 estimators, Cost: 0.022092518947734154
# Epoch 0, After 3 estimators, Cost: 0.021311671617942264
# Epoch 0, After 4 estimators, Cost: 8.260394485135222
# Epoch 0, After 5 estimators, Cost: 6.068788949941642
# Epoch 0, After 6 estimators, Cost: 3.9561411292502444
# Epoch 0, After 7 estimators, Cost: 7.574221291653159
# Epoch 0, After 8 estimators, Cost: 6.479499032799203
# Epoch 0, After 9 estimators, Cost: 1.2472475851659581
# Epoch 0, After 10 estimators, Cost: 2.7055402286360755
# Epoch 0, After 11 estimators, Cost: 0.2835037069354635
# Epoch 0, After 12 estimators, Cost: 3.166748864023032
# Epoch 0, After 13 estimators, Cost: 1.7398400030184726
# Epoch 0, After 14 estimators, Cost: 3.64127465636956
# Epoch 0, After 15 estimators, Cost: 1.6893657465222072
# Epoch 0, After 16 estimators, Cost: 0.18717998681888015
# Epoch 0, After 17 estimators, Cost: 2.770214205746351
# Epoch 0, After 18 estimators, Cost: 0.645770622943711
# Epoch 0, After 19 estimators, Cost: 5.980070055849735
# Epoch 0, After 20 estimators, Cost: 0.05497683913368682
# Epoch 0, After 21 estimators, Cost: 10.200885883486903
# Epoch 0, After 22 estimators, Cost: 1.380167037471864
# Epoch 0, After 23 estimators, Cost: 2.6490574157169595
# Epoch 0, After 24 estimators, Cost: 6.770686768922066
# Epoch 0, After 25 estimators, Cost: 2.1480224164981463
# Epoch 0, After 26 estimators, Cost: 4.1477465612838476
# Epoch 0, After 27 estimators, Cost: 8.562465038774967
# Epoch 0, After 28 estimators, Cost: 0.13099551320423514
# Epoch 0, After 29 estimators, Cost: 1.8817308050081014
# Epoch 0, After 30 estimators, Cost: 1.998175196703542
# Epoch 0, After 31 estimators, Cost: 6.136698466083243
# Epoch 0, After 32 estimators, Cost: 0.0005206184545796436
# Epoch 0, After 33 estimators, Cost: 11.946677160218576
# Epoch 0, After 34 estimators, Cost: 0.14119598469329223
# Epoch 0, After 35 estimators, Cost: 0.5456218732805895
# Epoch 0, After 36 estimators, Cost: 4.801010164650534
# Epoch 0, After 37 estimators, Cost: 3.545603464418387
# Epoch 0, After 38 estimators, Cost: 0.1279935473630363
# Epoch 0, After 39 estimators, Cost: 4.363809542935432
# Epoch 0, After 40 estimators, Cost: 3.5293662036189826
# Epoch 0, After 41 estimators, Cost: 1.0393636612983417
# Epoch 0, After 42 estimators, Cost: 9.423416690690491
# Epoch 0, After 43 estimators, Cost: 0.1675538719680588
# Epoch 0, After 44 estimators, Cost: 0.456636916904196
# Epoch 0, After 45 estimators, Cost: 2.964848647662825
# Epoch 0, After 46 estimators, Cost: 0.8786580343877283
# Epoch 0, After 47 estimators, Cost: 5.829887345720782
# Epoch 0, After 48 estimators, Cost: 7.145506167612369
# Epoch 0, After 49 estimators, Cost: 0.768214458163752
# Epoch 0, After 50 estimators, Cost: 0.8275449956232054
# Epoch 0, After 51 estimators, Cost: 0.49930725070988097
# Epoch 0, After 52 estimators, Cost: 0.22080578639556428
# Epoch 0, After 53 estimators, Cost: 1.4745043705820213
# Epoch 0, After 54 estimators, Cost: 1.0217418370583524
# Epoch 0, After 55 estimators, Cost: 4.60327387705301
# Epoch 0, After 56 estimators, Cost: 0.2898486311030984
# Epoch 0, After 57 estimators, Cost: 0.8645869549219665
# Epoch 0, After 58 estimators, Cost: 1.3289118636884658
# Epoch 0, After 59 estimators, Cost: 5.0171095547364555
# Epoch 0, After 60 estimators, Cost: 4.6473773956993965
# Epoch 0, After 61 estimators, Cost: 7.182785051562977
# Epoch 0, After 62 estimators, Cost: 1.5499913428233068e-05
# Epoch 0, After 63 estimators, Cost: 11.146387284521893
# Epoch 0, After 64 estimators, Cost: 2.514621004759166
# Epoch 0, After 65 estimators, Cost: 18.269540628995276
# Epoch 0, After 66 estimators, Cost: 4.681087182102017
# Epoch 0, After 67 estimators, Cost: 0.7401324488254943
# Epoch 0, After 68 estimators, Cost: 0.04330015695789354
# Epoch 0, After 69 estimators, Cost: 1.1915292627797527
# Epoch 0, After 70 estimators, Cost: 0.13543741431458703
# Epoch 0, After 71 estimators, Cost: 5.879915813589096
# Epoch 0, After 72 estimators, Cost: 2.18399186585554
# Epoch 0, After 73 estimators, Cost: 0.009057405961115586
# Epoch 0, After 74 estimators, Cost: 5.7384361640187135e-05
# Epoch 0, After 75 estimators, Cost: 0.6226630157780413
# Epoch 0, After 76 estimators, Cost: 0.007444129405516401
# Epoch 0, After 77 estimators, Cost: 4.590979970298366
# Epoch 0, After 78 estimators, Cost: 4.292344809200349
# Epoch 0, After 79 estimators, Cost: 0.028064747247242523
# Epoch 0, After 80 estimators, Cost: 0.0025755457050813282
# Epoch 0, After 81 estimators, Cost: 2.7450128482081793
# Epoch 0, After 82 estimators, Cost: 0.9275342936127094
# Epoch 0, After 83 estimators, Cost: 1.7617472681664859
# Epoch 0, After 84 estimators, Cost: 3.5743693135771757
# Epoch 0, After 85 estimators, Cost: 0.48076226691026397
# Epoch 0, After 86 estimators, Cost: 0.9450356873599803
# Epoch 0, After 87 estimators, Cost: 2.725788060248723
# Epoch 0, After 88 estimators, Cost: 0.03358012710488211
# Epoch 0, After 89 estimators, Cost: 7.474433048708684
# Epoch 0, After 90 estimators, Cost: 0.0009088885734742599
# Epoch 0, After 91 estimators, Cost: 0.17905133039645535
# Epoch 0, After 92 estimators, Cost: 0.4974330922659929
# Epoch 0, After 93 estimators, Cost: 3.5105753896215033
# Epoch 0, After 94 estimators, Cost: 0.2340994500169724
# Epoch 0, After 95 estimators, Cost: 29.50319719188474
# Epoch 0, After 96 estimators, Cost: 4.056585639568277
# Epoch 0, After 97 estimators, Cost: 8.125216747338865
# Epoch 0, After 98 estimators, Cost: 2.944831475102749
# Epoch 0, After 99 estimators, Cost: 3.4614525582259605
# Epoch 0, After 100 estimators, Cost: 0.15861141051937855
# Epoch 0, After 101 estimators, Cost: 2.291875889565966
# Epoch 0, After 102 estimators, Cost: 1.0232436370248
# Epoch 0, After 103 estimators, Cost: 1.428034132799049
# Epoch 0, After 104 estimators, Cost: 7.054799411633221
# Epoch 0, After 105 estimators, Cost: 3.2024185734328223
# Epoch 0, After 106 estimators, Cost: 16.459373159412298
# Epoch 0, After 107 estimators, Cost: 3.2098777239662004
# Epoch 0, After 108 estimators, Cost: 5.513066790893247
# Epoch 0, After 109 estimators, Cost: 0.2442687736375525
# Epoch 0, After 110 estimators, Cost: 1.6396704713053716
# Epoch 0, After 111 estimators, Cost: 6.546356757769918
# Epoch 0, After 112 estimators, Cost: 1.7244673740811525
# Epoch 0, After 113 estimators, Cost: 0.9516322911905313
# Epoch 0, After 114 estimators, Cost: 0.23842533836181828
# Epoch 0, After 115 estimators, Cost: 0.1841837325867759
# Epoch 0, After 116 estimators, Cost: 0.3169242888791715
# Epoch 0, After 117 estimators, Cost: 3.1643858212361753
# Epoch 0, After 118 estimators, Cost: 0.15707260059282
# Epoch 0, After 119 estimators, Cost: 0.7802118112056566
# Epoch 0, After 120 estimators, Cost: 5.763901922032671
# Epoch 0, After 121 estimators, Cost: 0.06738424931961441
# Epoch 0, After 122 estimators, Cost: 0.0702600351987432
# Epoch 0, After 123 estimators, Cost: 2.1254588412048734
# Epoch 0, After 124 estimators, Cost: 0.943869227742203
# Epoch 0, After 125 estimators, Cost: 6.583886832165141
# Epoch 0, After 126 estimators, Cost: 0.9856817585129121
# Epoch 0, After 127 estimators, Cost: 0.25063588656105484
# Epoch 0, After 128 estimators, Cost: 1.6913354029025403
# Epoch 0, After 129 estimators, Cost: 5.896799308911607
# Epoch 0, After 130 estimators, Cost: 0.2717973133180812
# Epoch 0, After 131 estimators, Cost: 1.6196598024889803
# Epoch 0, After 132 estimators, Cost: 0.6503391895030453
# Epoch 0, After 133 estimators, Cost: 1.199962603273876
# Epoch 0, After 134 estimators, Cost: 0.2596720517326244
# Epoch 0, After 135 estimators, Cost: 4.59951789512513
# Epoch 0, After 136 estimators, Cost: 0.052016874718976015
# Epoch 0, After 137 estimators, Cost: 2.336190348107345
# Epoch 0, After 138 estimators, Cost: 14.890157087675886
# Epoch 0, After 139 estimators, Cost: 1.0439311820156898
# Epoch 0, After 140 estimators, Cost: 9.013140368184043
# Epoch 0, After 141 estimators, Cost: 1.3833998608024947
# Epoch 0, After 142 estimators, Cost: 8.58670902546416
# Epoch 0, After 143 estimators, Cost: 0.9999803105764412
# Epoch 0, After 144 estimators, Cost: 4.556402758358931
# Epoch 0, After 145 estimators, Cost: 3.415376225645517
# Epoch 0, After 146 estimators, Cost: 0.20548334302704893
# Epoch 0, After 147 estimators, Cost: 2.432485950172423
# Epoch 0, After 148 estimators, Cost: 4.720413689991069
# Epoch 0, After 149 estimators, Cost: 0.42640653608193285
# Epoch 1, After 0 estimators, Cost: 2.3491594606158768
# Epoch 1, After 1 estimators, Cost: 0.0001868325729205909
# Epoch 1, After 2 estimators, Cost: 0.8030276950092352
# Epoch 1, After 3 estimators, Cost: 0.04080240965039628
# Epoch 1, After 4 estimators, Cost: 6.672076154050999
# Epoch 1, After 5 estimators, Cost: 4.728223364693429
# Epoch 1, After 6 estimators, Cost: 3.4322110095413336
# Epoch 1, After 7 estimators, Cost: 0.9592329233674518
# Epoch 1, After 8 estimators, Cost: 7.754661701575737
# Epoch 1, After 9 estimators, Cost: 0.25386021010734117
# Epoch 1, After 10 estimators, Cost: 2.1509658175927484
# Epoch 1, After 11 estimators, Cost: 1.7505240317163524
# Epoch 1, After 12 estimators, Cost: 1.4250090842528835
# Epoch 1, After 13 estimators, Cost: 0.9059188268627224
# Epoch 1, After 14 estimators, Cost: 2.3522101036703957
# Epoch 1, After 15 estimators, Cost: 0.8601957189079501
# Epoch 1, After 16 estimators, Cost: 0.012819671047669005
# Epoch 1, After 17 estimators, Cost: 2.4573274024708125
# Epoch 1, After 18 estimators, Cost: 0.35221458413802
# Epoch 1, After 19 estimators, Cost: 4.491383449820184
# Epoch 1, After 20 estimators, Cost: 0.07521651480162139
# Epoch 1, After 21 estimators, Cost: 7.948764674263082
# Epoch 1, After 22 estimators, Cost: 0.723987301059067
# Epoch 1, After 23 estimators, Cost: 1.8413365849962382
# Epoch 1, After 24 estimators, Cost: 5.863732770468282
# Epoch 1, After 25 estimators, Cost: 1.150348348612795
# Epoch 1, After 26 estimators, Cost: 2.798549649134538
# Epoch 1, After 27 estimators, Cost: 7.898564118202564
# Epoch 1, After 28 estimators, Cost: 0.13448665107915164
# Epoch 1, After 29 estimators, Cost: 1.0062357878830304
# Epoch 1, After 30 estimators, Cost: 2.0649288603003133
# Epoch 1, After 31 estimators, Cost: 4.461389397403102
# Epoch 1, After 32 estimators, Cost: 0.14650540747505889
# Epoch 1, After 33 estimators, Cost: 7.074110698912121
# Epoch 1, After 34 estimators, Cost: 0.017528303204395742
# Epoch 1, After 35 estimators, Cost: 0.7119668325176101
# Epoch 1, After 36 estimators, Cost: 3.5243564317350637
# Epoch 1, After 37 estimators, Cost: 2.133618834559275
# Epoch 1, After 38 estimators, Cost: 0.11289081874961282
# Epoch 1, After 39 estimators, Cost: 3.482165504096863
# Epoch 1, After 40 estimators, Cost: 2.170341092130916
# Epoch 1, After 41 estimators, Cost: 0.7046125389427504
# Epoch 1, After 42 estimators, Cost: 6.957816953882689
# Epoch 1, After 43 estimators, Cost: 0.02105356184309977
# Epoch 1, After 44 estimators, Cost: 0.11604506980799513
# Epoch 1, After 45 estimators, Cost: 2.7871771358637525
# Epoch 1, After 46 estimators, Cost: 0.40045799545442595
# Epoch 1, After 47 estimators, Cost: 5.059672949968053
# Epoch 1, After 48 estimators, Cost: 6.399674957840484
# Epoch 1, After 49 estimators, Cost: 0.2561646918164592
# Epoch 1, After 50 estimators, Cost: 0.39840145623688555
# Epoch 1, After 51 estimators, Cost: 0.501911229298438
# Epoch 1, After 52 estimators, Cost: 0.1174794525997318
# Epoch 1, After 53 estimators, Cost: 1.5998994070624941
# Epoch 1, After 54 estimators, Cost: 0.7632116306554966
# Epoch 1, After 55 estimators, Cost: 4.338584343501214
# Epoch 1, After 56 estimators, Cost: 0.010959642026526538
# Epoch 1, After 57 estimators, Cost: 0.31642268969887166
# Epoch 1, After 58 estimators, Cost: 0.4976494850653582
# Epoch 1, After 59 estimators, Cost: 3.792137907454529
# Epoch 1, After 60 estimators, Cost: 3.6085531496819647
# Epoch 1, After 61 estimators, Cost: 5.565123383721794
# Epoch 1, After 62 estimators, Cost: 0.0011280951776823892
# Epoch 1, After 63 estimators, Cost: 9.396148108939254
# Epoch 1, After 64 estimators, Cost: 1.6157217876717804
# Epoch 1, After 65 estimators, Cost: 16.90671996195527
# Epoch 1, After 66 estimators, Cost: 3.159154695948944
# Epoch 1, After 67 estimators, Cost: 0.707208700880574
# Epoch 1, After 68 estimators, Cost: 0.04250480480141467
# Epoch 1, After 69 estimators, Cost: 0.8226257970492971
# Epoch 1, After 70 estimators, Cost: 0.10931168041625747
# Epoch 1, After 71 estimators, Cost: 4.286318053284
# Epoch 1, After 72 estimators, Cost: 1.061153439397065
# Epoch 1, After 73 estimators, Cost: 0.013442293099444256
# Epoch 1, After 74 estimators, Cost: 0.0025787045415116188
# Epoch 1, After 75 estimators, Cost: 0.6861363778483595
# Epoch 1, After 76 estimators, Cost: 0.006526198206962993
# Epoch 1, After 77 estimators, Cost: 3.0317293120923576
# Epoch 1, After 78 estimators, Cost: 3.2541555975608287
# Epoch 1, After 79 estimators, Cost: 0.04439284240935774
# Epoch 1, After 80 estimators, Cost: 0.0017989045003012644
# Epoch 1, After 81 estimators, Cost: 2.399529330773649
# Epoch 1, After 82 estimators, Cost: 0.46524960083907413
# Epoch 1, After 83 estimators, Cost: 0.8714415851948373
# Epoch 1, After 84 estimators, Cost: 2.563686128850253
# Epoch 1, After 85 estimators, Cost: 0.16931352533087232
# Epoch 1, After 86 estimators, Cost: 0.9132210509949967
# Epoch 1, After 87 estimators, Cost: 2.4452219266388977
# Epoch 1, After 88 estimators, Cost: 0.09907084642592967
# Epoch 1, After 89 estimators, Cost: 6.411480927460218
# Epoch 1, After 90 estimators, Cost: 0.15948931869334868
# Epoch 1, After 91 estimators, Cost: 0.2093822672151605
# Epoch 1, After 92 estimators, Cost: 0.5061450849646226
# Epoch 1, After 93 estimators, Cost: 2.994486532514183
# Epoch 1, After 94 estimators, Cost: 0.2527790350800258
# Epoch 1, After 95 estimators, Cost: 27.518548432505025
# Epoch 1, After 96 estimators, Cost: 3.4144117709940605
# Epoch 1, After 97 estimators, Cost: 6.897879384118636
# Epoch 1, After 98 estimators, Cost: 1.7586118037387772
# Epoch 1, After 99 estimators, Cost: 2.2535208876297803
# Epoch 1, After 100 estimators, Cost: 0.0008257349660993806
# Epoch 1, After 101 estimators, Cost: 2.0950110522139176
# Epoch 1, After 102 estimators, Cost: 0.5333100850500633
# Epoch 1, After 103 estimators, Cost: 1.0575656905903137
# Epoch 1, After 104 estimators, Cost: 5.8760348832070015
# Epoch 1, After 105 estimators, Cost: 2.1936205502852317
# Epoch 1, After 106 estimators, Cost: 14.631448428339144
# Epoch 1, After 107 estimators, Cost: 3.1472654539702827
# Epoch 1, After 108 estimators, Cost: 4.1324894360506725
# Epoch 1, After 109 estimators, Cost: 0.7275482530711581
# Epoch 1, After 110 estimators, Cost: 0.9835779071765767
# Epoch 1, After 111 estimators, Cost: 4.9560302347250325
# Epoch 1, After 112 estimators, Cost: 1.209935083263064
# Epoch 1, After 113 estimators, Cost: 0.8895169222796018
# Epoch 1, After 114 estimators, Cost: 0.15019733616821304
# Epoch 1, After 115 estimators, Cost: 0.2671780697632902
# Epoch 1, After 116 estimators, Cost: 0.3012889801687783
# Epoch 1, After 117 estimators, Cost: 2.1057687158757323
# Epoch 1, After 118 estimators, Cost: 0.09676339805029072
# Epoch 1, After 119 estimators, Cost: 0.5143755427365524
# Epoch 1, After 120 estimators, Cost: 5.793916030146217
# Epoch 1, After 121 estimators, Cost: 0.03579662889783117
# Epoch 1, After 122 estimators, Cost: 0.291467768755357
# Epoch 1, After 123 estimators, Cost: 1.216798039424289
# Epoch 1, After 124 estimators, Cost: 0.43803344923073473
# Epoch 1, After 125 estimators, Cost: 5.488084720949253
# Epoch 1, After 126 estimators, Cost: 0.9642516720822143
# Epoch 1, After 127 estimators, Cost: 0.2126149783890767
# Epoch 1, After 128 estimators, Cost: 0.8463322440480858
# Epoch 1, After 129 estimators, Cost: 5.059625050980336
# Epoch 1, After 130 estimators, Cost: 0.08698719952145306
# Epoch 1, After 131 estimators, Cost: 0.9321400190167788
# Epoch 1, After 132 estimators, Cost: 0.2204560234946997
# Epoch 1, After 133 estimators, Cost: 0.6959024216621479
# Epoch 1, After 134 estimators, Cost: 0.43419573107128606
# Epoch 1, After 135 estimators, Cost: 3.525750247081129
# Epoch 1, After 136 estimators, Cost: 0.002685380576486216
# Epoch 1, After 137 estimators, Cost: 2.1312604403378037
# Epoch 1, After 138 estimators, Cost: 13.031478664885986
# Epoch 1, After 139 estimators, Cost: 0.7871996123260047
# Epoch 1, After 140 estimators, Cost: 8.618624505082321
# Epoch 1, After 141 estimators, Cost: 0.7778262814584481
# Epoch 1, After 142 estimators, Cost: 7.501159409552321
# Epoch 1, After 143 estimators, Cost: 0.5273037988990523
# Epoch 1, After 144 estimators, Cost: 3.4407735020271435
# Epoch 1, After 145 estimators, Cost: 2.1877869539341344
# Epoch 1, After 146 estimators, Cost: 0.10294293395937208
# Epoch 1, After 147 estimators, Cost: 1.893091250053485
# Epoch 1, After 148 estimators, Cost: 6.374077671777495
# Epoch 1, After 149 estimators, Cost: 0.1404345261982713
# Epoch 2, After 0 estimators, Cost: 1.6707741411504782
# Epoch 2, After 1 estimators, Cost: 0.00989328530966759
# Epoch 2, After 2 estimators, Cost: 0.6884542727245391
# Epoch 2, After 3 estimators, Cost: 0.004472253845959444
# Epoch 2, After 4 estimators, Cost: 5.130071166431184
# Epoch 2, After 5 estimators, Cost: 3.4541777342898334
# Epoch 2, After 6 estimators, Cost: 2.2954592276904306
# Epoch 2, After 7 estimators, Cost: 0.8485585492946043
# Epoch 2, After 8 estimators, Cost: 7.055755510055632
# Epoch 2, After 9 estimators, Cost: 0.31772136823122105
# Epoch 2, After 10 estimators, Cost: 1.2786737515144766
# Epoch 2, After 11 estimators, Cost: 2.2517499436653527
# Epoch 2, After 12 estimators, Cost: 1.422450376137128
# Epoch 2, After 13 estimators, Cost: 0.4326713596035286
# Epoch 2, After 14 estimators, Cost: 1.518033407918551
# Epoch 2, After 15 estimators, Cost: 0.3941260716180803
# Epoch 2, After 16 estimators, Cost: 0.022175730845787178
# Epoch 2, After 17 estimators, Cost: 1.9509810004658454
# Epoch 2, After 18 estimators, Cost: 0.14533532327460538
# Epoch 2, After 19 estimators, Cost: 3.4372745782027776
# Epoch 2, After 20 estimators, Cost: 0.023154036129219575
# Epoch 2, After 21 estimators, Cost: 6.317043704789928
# Epoch 2, After 22 estimators, Cost: 0.34511836653262334
# Epoch 2, After 23 estimators, Cost: 1.255363724174784
# Epoch 2, After 24 estimators, Cost: 4.943551411437471
# Epoch 2, After 25 estimators, Cost: 1.1488005199013098
# Epoch 2, After 26 estimators, Cost: 1.9163118268890382
# Epoch 2, After 27 estimators, Cost: 6.979837452239773
# Epoch 2, After 28 estimators, Cost: 0.24058883399417777
# Epoch 2, After 29 estimators, Cost: 0.4776574517046036
# Epoch 2, After 30 estimators, Cost: 1.765253447009308
# Epoch 2, After 31 estimators, Cost: 3.3226099943915925
# Epoch 2, After 32 estimators, Cost: 0.4646245239928923
# Epoch 2, After 33 estimators, Cost: 6.0035613705679465
# Epoch 2, After 34 estimators, Cost: 0.07420373366446346
# Epoch 2, After 35 estimators, Cost: 0.6725027013392821
# Epoch 2, After 36 estimators, Cost: 2.6327738478632337
# Epoch 2, After 37 estimators, Cost: 1.3311212237246774
# Epoch 2, After 38 estimators, Cost: 0.06185136227789597
# Epoch 2, After 39 estimators, Cost: 2.7603002127722887
# Epoch 2, After 40 estimators, Cost: 1.3832953345331007
# Epoch 2, After 41 estimators, Cost: 0.43555615247550256
# Epoch 2, After 42 estimators, Cost: 5.4485104093554915
# Epoch 2, After 43 estimators, Cost: 0.001471829764882898
# Epoch 2, After 44 estimators, Cost: 0.005896832498386973
# Epoch 2, After 45 estimators, Cost: 2.482766780919666
# Epoch 2, After 46 estimators, Cost: 0.1478261477434613
# Epoch 2, After 47 estimators, Cost: 4.337813873411705
# Epoch 2, After 48 estimators, Cost: 5.653456350019947
# Epoch 2, After 49 estimators, Cost: 0.05190432021734881
# Epoch 2, After 50 estimators, Cost: 0.22418885949940806
# Epoch 2, After 51 estimators, Cost: 0.4458098433931892
# Epoch 2, After 52 estimators, Cost: 0.0727027668855927
# Epoch 2, After 53 estimators, Cost: 1.64514197682707
# Epoch 2, After 54 estimators, Cost: 0.5371317335613158
# Epoch 2, After 55 estimators, Cost: 4.175115354364774
# Epoch 2, After 56 estimators, Cost: 0.03895292776696274
# Epoch 2, After 57 estimators, Cost: 0.08197618267078698
# Epoch 2, After 58 estimators, Cost: 0.1631639794438309
# Epoch 2, After 59 estimators, Cost: 2.9124371586195212
# Epoch 2, After 60 estimators, Cost: 2.8199120878501094
# Epoch 2, After 61 estimators, Cost: 4.428989125187648
# Epoch 2, After 62 estimators, Cost: 0.0011776345722827016
# Epoch 2, After 63 estimators, Cost: 8.040040078879844
# Epoch 2, After 64 estimators, Cost: 1.0404885465592921
# Epoch 2, After 65 estimators, Cost: 15.634512202348827
# Epoch 2, After 66 estimators, Cost: 2.2459770106765036
# Epoch 2, After 67 estimators, Cost: 0.7165855862944608
# Epoch 2, After 68 estimators, Cost: 0.2396652061019671
# Epoch 2, After 69 estimators, Cost: 0.5659796956096829
# Epoch 2, After 70 estimators, Cost: 0.07665800481468592
# Epoch 2, After 71 estimators, Cost: 3.251568795910891
# Epoch 2, After 72 estimators, Cost: 0.5472501531313074
# Epoch 2, After 73 estimators, Cost: 0.012466146659852191
# Epoch 2, After 74 estimators, Cost: 0.015185775055196917
# Epoch 2, After 75 estimators, Cost: 0.7788571404351392
# Epoch 2, After 76 estimators, Cost: 0.003480539507944928
# Epoch 2, After 77 estimators, Cost: 2.1541628875110885
# Epoch 2, After 78 estimators, Cost: 2.4911905928301814
# Epoch 2, After 79 estimators, Cost: 0.22825849001126758
# Epoch 2, After 80 estimators, Cost: 0.012254606236302387
# Epoch 2, After 81 estimators, Cost: 2.0664514329914536
# Epoch 2, After 82 estimators, Cost: 0.20224645970205996
# Epoch 2, After 83 estimators, Cost: 0.4467019863470889
# Epoch 2, After 84 estimators, Cost: 1.8626911041354766
# Epoch 2, After 85 estimators, Cost: 0.03208055131893392
# Epoch 2, After 86 estimators, Cost: 0.8505775435324259
# Epoch 2, After 87 estimators, Cost: 2.1608402816946515
# Epoch 2, After 88 estimators, Cost: 0.1793749322653949
# Epoch 2, After 89 estimators, Cost: 5.518414145339952
# Epoch 2, After 90 estimators, Cost: 0.4362333890173622
# Epoch 2, After 91 estimators, Cost: 0.2546142220320787
# Epoch 2, After 92 estimators, Cost: 0.4937996873235566
# Epoch 2, After 93 estimators, Cost: 2.5357778856774713
# Epoch 2, After 94 estimators, Cost: 0.25773366620863675
# Epoch 2, After 95 estimators, Cost: 25.76052573279197
# Epoch 2, After 96 estimators, Cost: 2.864373270071856
# Epoch 2, After 97 estimators, Cost: 5.902397736117189
# Epoch 2, After 98 estimators, Cost: 1.158985431921143
# Epoch 2, After 99 estimators, Cost: 1.563637584233128
# Epoch 2, After 100 estimators, Cost: 0.043707239403796366
# Epoch 2, After 101 estimators, Cost: 1.8810899276230373
# Epoch 2, After 102 estimators, Cost: 0.24989283957682584
# Epoch 2, After 103 estimators, Cost: 0.7618434696937088
# Epoch 2, After 104 estimators, Cost: 4.969691919145073
# Epoch 2, After 105 estimators, Cost: 1.5358111437624362
# Epoch 2, After 106 estimators, Cost: 13.127925071342649
# Epoch 2, After 107 estimators, Cost: 3.1494034168505673
# Epoch 2, After 108 estimators, Cost: 3.2021838053909075
# Epoch 2, After 109 estimators, Cost: 1.202175258486328
# Epoch 2, After 110 estimators, Cost: 0.5759770512403289
# Epoch 2, After 111 estimators, Cost: 3.9302928890781477
# Epoch 2, After 112 estimators, Cost: 0.844360978758856
# Epoch 2, After 113 estimators, Cost: 0.8618562916626115
# Epoch 2, After 114 estimators, Cost: 0.08076884792232633
# Epoch 2, After 115 estimators, Cost: 0.34607457856735874
# Epoch 2, After 116 estimators, Cost: 0.29856613491800515
# Epoch 2, After 117 estimators, Cost: 1.4535861308822033
# Epoch 2, After 118 estimators, Cost: 0.056122042916819916
# Epoch 2, After 119 estimators, Cost: 0.31514642381062274
# Epoch 2, After 120 estimators, Cost: 5.781378417466541
# Epoch 2, After 121 estimators, Cost: 0.015719375658432656
# Epoch 2, After 122 estimators, Cost: 0.5862012677597566
# Epoch 2, After 123 estimators, Cost: 0.7279411988724236
# Epoch 2, After 124 estimators, Cost: 0.17844441671921749
# Epoch 2, After 125 estimators, Cost: 4.607408851360873
# Epoch 2, After 126 estimators, Cost: 0.9615748137259372
# Epoch 2, After 127 estimators, Cost: 0.18437534109662945
# Epoch 2, After 128 estimators, Cost: 0.45903125832686364
# Epoch 2, After 129 estimators, Cost: 4.342357260474464
# Epoch 2, After 130 estimators, Cost: 0.009423738128528428
# Epoch 2, After 131 estimators, Cost: 0.5310639459540746
# Epoch 2, After 132 estimators, Cost: 0.052968339208232594
# Epoch 2, After 133 estimators, Cost: 0.38022929422026475
# Epoch 2, After 134 estimators, Cost: 0.6202313113257129
# Epoch 2, After 135 estimators, Cost: 2.7467983199030597
# Epoch 2, After 136 estimators, Cost: 0.012556623091690365
# Epoch 2, After 137 estimators, Cost: 1.9162810645608346
# Epoch 2, After 138 estimators, Cost: 11.555429795291658
# Epoch 2, After 139 estimators, Cost: 0.5843698189663734
# Epoch 2, After 140 estimators, Cost: 8.271532309396683
# Epoch 2, After 141 estimators, Cost: 0.4228171153140162
# Epoch 2, After 142 estimators, Cost: 6.570568966738763
# Epoch 2, After 143 estimators, Cost: 0.2534213072760999
# Epoch 2, After 144 estimators, Cost: 2.6563779914102734
# Epoch 2, After 145 estimators, Cost: 1.5203946914296809
# Epoch 2, After 146 estimators, Cost: 0.03586972881211382
# Epoch 2, After 147 estimators, Cost: 1.4556222087498571
# Epoch 2, After 148 estimators, Cost: 7.627871075957436
# Epoch 2, After 149 estimators, Cost: 0.02292305437413821
# Epoch 3, After 0 estimators, Cost: 1.1833197381722138
# Epoch 3, After 1 estimators, Cost: 0.03574621757495715
# Epoch 3, After 2 estimators, Cost: 0.5693412608329245
# Epoch 3, After 3 estimators, Cost: 0.004277837649857473
# Epoch 3, After 4 estimators, Cost: 4.125767710394118
# Epoch 3, After 5 estimators, Cost: 2.6450773095030096
# Epoch 3, After 6 estimators, Cost: 1.6570195876638276
# Epoch 3, After 7 estimators, Cost: 0.7817100437510976
# Epoch 3, After 8 estimators, Cost: 6.399855181416721
# Epoch 3, After 9 estimators, Cost: 0.3989304943191349
# Epoch 3, After 10 estimators, Cost: 0.8357392019884353
# Epoch 3, After 11 estimators, Cost: 2.725941747144917
# Epoch 3, After 12 estimators, Cost: 1.4513496101956227
# Epoch 3, After 13 estimators, Cost: 0.18650384827944858
# Epoch 3, After 14 estimators, Cost: 1.0109804900577364
# Epoch 3, After 15 estimators, Cost: 0.16190065169414342
# Epoch 3, After 16 estimators, Cost: 0.13192301890627933
# Epoch 3, After 17 estimators, Cost: 1.532294017765884
# Epoch 3, After 18 estimators, Cost: 0.03766688108702921
# Epoch 3, After 19 estimators, Cost: 2.686175650444455
# Epoch 3, After 20 estimators, Cost: 0.0009966709107560505
# Epoch 3, After 21 estimators, Cost: 5.2510329601444745
# Epoch 3, After 22 estimators, Cost: 0.1397292415320864
# Epoch 3, After 23 estimators, Cost: 0.8456717843188318
# Epoch 3, After 24 estimators, Cost: 4.186928537216336
# Epoch 3, After 25 estimators, Cost: 1.1766272939440867
# Epoch 3, After 26 estimators, Cost: 1.3571135634546476
# Epoch 3, After 27 estimators, Cost: 6.180861335039845
# Epoch 3, After 28 estimators, Cost: 0.373541142365415
# Epoch 3, After 29 estimators, Cost: 0.23611069904767962
# Epoch 3, After 30 estimators, Cost: 1.489241394635492
# Epoch 3, After 31 estimators, Cost: 2.5850576503135763
# Epoch 3, After 32 estimators, Cost: 0.7777375694652188
# Epoch 3, After 33 estimators, Cost: 5.169524714577819
# Epoch 3, After 34 estimators, Cost: 0.15400393479365193
# Epoch 3, After 35 estimators, Cost: 0.6191180345655043
# Epoch 3, After 36 estimators, Cost: 1.9996934650059162
# Epoch 3, After 37 estimators, Cost: 0.8807170869454412
# Epoch 3, After 38 estimators, Cost: 0.02494979484966176
# Epoch 3, After 39 estimators, Cost: 2.1913608254444297
# Epoch 3, After 40 estimators, Cost: 0.9284740348815884
# Epoch 3, After 41 estimators, Cost: 0.24621229751043716
# Epoch 3, After 42 estimators, Cost: 4.5608765260111115
# Epoch 3, After 43 estimators, Cost: 0.00204315052586323
# Epoch 3, After 44 estimators, Cost: 0.01773204740716851
# Epoch 3, After 45 estimators, Cost: 2.1886535049903313
# Epoch 3, After 46 estimators, Cost: 0.03245780320757699
# Epoch 3, After 47 estimators, Cost: 3.7197200989779584
# Epoch 3, After 48 estimators, Cost: 4.994656083100257
# Epoch 3, After 49 estimators, Cost: 0.0003244944890496364
# Epoch 3, After 50 estimators, Cost: 0.11225051892884298
# Epoch 3, After 51 estimators, Cost: 0.38383048879065945
# Epoch 3, After 52 estimators, Cost: 0.04231054251556723
# Epoch 3, After 53 estimators, Cost: 1.6748033937002988
# Epoch 3, After 54 estimators, Cost: 0.35828904567346687
# Epoch 3, After 55 estimators, Cost: 4.033046195271846
# Epoch 3, After 56 estimators, Cost: 0.16644920366478685
# Epoch 3, After 57 estimators, Cost: 0.005760092070449521
# Epoch 3, After 58 estimators, Cost: 0.04103804721173817
# Epoch 3, After 59 estimators, Cost: 2.270127334071472
# Epoch 3, After 60 estimators, Cost: 2.218849565260952
# Epoch 3, After 61 estimators, Cost: 3.6104038018996962
# Epoch 3, After 62 estimators, Cost: 0.0005281743799090956
# Epoch 3, After 63 estimators, Cost: 6.975954015434542
# Epoch 3, After 64 estimators, Cost: 0.6678475689602347
# Epoch 3, After 65 estimators, Cost: 14.49136510717829
# Epoch 3, After 66 estimators, Cost: 1.678552109100487
# Epoch 3, After 67 estimators, Cost: 0.7444688935819249
# Epoch 3, After 68 estimators, Cost: 0.46648018627786536
# Epoch 3, After 69 estimators, Cost: 0.3794531871741185
# Epoch 3, After 70 estimators, Cost: 0.04715912566879039
# Epoch 3, After 71 estimators, Cost: 2.5569928587207866
# Epoch 3, After 72 estimators, Cost: 0.3080588822926792
# Epoch 3, After 73 estimators, Cost: 0.008875738202013098
# Epoch 3, After 74 estimators, Cost: 0.04005302173102526
# Epoch 3, After 75 estimators, Cost: 0.8881779897529982
# Epoch 3, After 76 estimators, Cost: 0.0008649841726238149
# Epoch 3, After 77 estimators, Cost: 1.6422901069793379
# Epoch 3, After 78 estimators, Cost: 1.9247589197399846
# Epoch 3, After 79 estimators, Cost: 0.4459538827133001
# Epoch 3, After 80 estimators, Cost: 0.02640729572304928
# Epoch 3, After 81 estimators, Cost: 1.7657851432328988
# Epoch 3, After 82 estimators, Cost: 0.0655027532797871
# Epoch 3, After 83 estimators, Cost: 0.24057513243390796
# Epoch 3, After 84 estimators, Cost: 1.3685626398769533
# Epoch 3, After 85 estimators, Cost: 0.00019974674293016812
# Epoch 3, After 86 estimators, Cost: 0.7759575652627894
# Epoch 3, After 87 estimators, Cost: 1.8953413317488046
# Epoch 3, After 88 estimators, Cost: 0.2652740839369813
# Epoch 3, After 89 estimators, Cost: 4.775011477401409
# Epoch 3, After 90 estimators, Cost: 0.7168898456303757
# Epoch 3, After 91 estimators, Cost: 0.3099245629655993
# Epoch 3, After 92 estimators, Cost: 0.4704888213304839
# Epoch 3, After 93 estimators, Cost: 2.141551413018471
# Epoch 3, After 94 estimators, Cost: 0.2544336835386692
# Epoch 3, After 95 estimators, Cost: 24.222582764901205
# Epoch 3, After 96 estimators, Cost: 2.4031827601372897
# Epoch 3, After 97 estimators, Cost: 5.094302442568281
# Epoch 3, After 98 estimators, Cost: 0.8472275263548891
# Epoch 3, After 99 estimators, Cost: 1.1545177645192264
# Epoch 3, After 100 estimators, Cost: 0.12888483052605768
# Epoch 3, After 101 estimators, Cost: 1.673097332810277
# Epoch 3, After 102 estimators, Cost: 0.0956900800930974
# Epoch 3, After 103 estimators, Cost: 0.5336685950275829
# Epoch 3, After 104 estimators, Cost: 4.261603990098212
# Epoch 3, After 105 estimators, Cost: 1.0963507496887424
# Epoch 3, After 106 estimators, Cost: 11.886879958032939
# Epoch 3, After 107 estimators, Cost: 3.1889549323490836
# Epoch 3, After 108 estimators, Cost: 2.556029239835711
# Epoch 3, After 109 estimators, Cost: 1.5915569328711998
# Epoch 3, After 110 estimators, Cost: 0.3237700558843072
# Epoch 3, After 111 estimators, Cost: 3.24518434280657
# Epoch 3, After 112 estimators, Cost: 0.5840150236705831
# Epoch 3, After 113 estimators, Cost: 0.8546236553665977
# Epoch 3, After 114 estimators, Cost: 0.03377102256942505
# Epoch 3, After 115 estimators, Cost: 0.41875838418298267
# Epoch 3, After 116 estimators, Cost: 0.3033556325218133
# Epoch 3, After 117 estimators, Cost: 1.0386263099201498
# Epoch 3, After 118 estimators, Cost: 0.02970528090959162
# Epoch 3, After 119 estimators, Cost: 0.17496646406992933
# Epoch 3, After 120 estimators, Cost: 5.7446009606459025
# Epoch 3, After 121 estimators, Cost: 0.00463717778308273
# Epoch 3, After 122 estimators, Cost: 0.9079156654391182
# Epoch 3, After 123 estimators, Cost: 0.45669945923133715
# Epoch 3, After 124 estimators, Cost: 0.05506009218853959
# Epoch 3, After 125 estimators, Cost: 3.8992310288841328
# Epoch 3, After 126 estimators, Cost: 0.9699349521971787
# Epoch 3, After 127 estimators, Cost: 0.16290304071068545
# Epoch 3, After 128 estimators, Cost: 0.277511782620687
# Epoch 3, After 129 estimators, Cost: 3.7376842581618153
# Epoch 3, After 130 estimators, Cost: 0.005700542102359771
# Epoch 3, After 131 estimators, Cost: 0.29553841300815753
# Epoch 3, After 132 estimators, Cost: 0.0034173010480804443
# Epoch 3, After 133 estimators, Cost: 0.18840983340656045
# Epoch 3, After 134 estimators, Cost: 0.8072424042223962
# Epoch 3, After 135 estimators, Cost: 2.1722976052305603
# Epoch 3, After 136 estimators, Cost: 0.06844964956427971
# Epoch 3, After 137 estimators, Cost: 1.7104101489015582
# Epoch 3, After 138 estimators, Cost: 10.370322950780233
# Epoch 3, After 139 estimators, Cost: 0.42740164431966454
# Epoch 3, After 140 estimators, Cost: 7.968247379911946
# Epoch 3, After 141 estimators, Cost: 0.21649505144991496
# Epoch 3, After 142 estimators, Cost: 5.782675812467646
# Epoch 3, After 143 estimators, Cost: 0.10258165336399123
# Epoch 3, After 144 estimators, Cost: 2.0923864083176826
# Epoch 3, After 145 estimators, Cost: 1.14462806812807
# Epoch 3, After 146 estimators, Cost: 0.004116076205641416
# Epoch 3, After 147 estimators, Cost: 1.1083562359466466
# Epoch 3, After 148 estimators, Cost: 8.533522488639044
# Epoch 3, After 149 estimators, Cost: 0.0009024074372801254
# Epoch 4, After 0 estimators, Cost: 0.8328395597474092
# Epoch 4, After 1 estimators, Cost: 0.06810999918706123
# Epoch 4, After 2 estimators, Cost: 0.4588719973669321
# Epoch 4, After 3 estimators, Cost: 0.036232832573541235
# Epoch 4, After 4 estimators, Cost: 3.448770873737849
# Epoch 4, After 5 estimators, Cost: 2.1125137788751043
# Epoch 4, After 6 estimators, Cost: 1.285500569597032
# Epoch 4, After 7 estimators, Cost: 0.7416404123604616
# Epoch 4, After 8 estimators, Cost: 5.807613702106811
# Epoch 4, After 9 estimators, Cost: 0.49199542259777324
# Epoch 4, After 10 estimators, Cost: 0.6038609350972318
# Epoch 4, After 11 estimators, Cost: 3.1653131665000114
# Epoch 4, After 12 estimators, Cost: 1.498147458893557
# Epoch 4, After 13 estimators, Cost: 0.06539435857708352
# Epoch 4, After 14 estimators, Cost: 0.6934459565128885
# Epoch 4, After 15 estimators, Cost: 0.053046892796648634
# Epoch 4, After 16 estimators, Cost: 0.29177275461533453
# Epoch 4, After 17 estimators, Cost: 1.194102233619516
# Epoch 4, After 18 estimators, Cost: 0.0008834607615876344
# Epoch 4, After 19 estimators, Cost: 2.139581217359276
# Epoch 4, After 20 estimators, Cost: 0.0068857122986635926
# Epoch 4, After 21 estimators, Cost: 4.531334623088017
# Epoch 4, After 22 estimators, Cost: 0.039434380518753996
# Epoch 4, After 23 estimators, Cost: 0.5601040467879573
# Epoch 4, After 24 estimators, Cost: 3.5678591414980056
# Epoch 4, After 25 estimators, Cost: 1.221245002013716
# Epoch 4, After 26 estimators, Cost: 0.9915205765987557
# Epoch 4, After 27 estimators, Cost: 5.496566683299843
# Epoch 4, After 28 estimators, Cost: 0.5254427509885198
# Epoch 4, After 29 estimators, Cost: 0.12415886161352657
# Epoch 4, After 30 estimators, Cost: 1.2471082304429204
# Epoch 4, After 31 estimators, Cost: 2.0904627049002666
# Epoch 4, After 32 estimators, Cost: 1.0312523680738914
# Epoch 4, After 33 estimators, Cost: 4.511635419725375
# Epoch 4, After 34 estimators, Cost: 0.24557870582267075
# Epoch 4, After 35 estimators, Cost: 0.5616659488152738
# Epoch 4, After 36 estimators, Cost: 1.5420678096733207
# Epoch 4, After 37 estimators, Cost: 0.6184126654213971
# Epoch 4, After 38 estimators, Cost: 0.004769631222577436
# Epoch 4, After 39 estimators, Cost: 1.744658876772717
# Epoch 4, After 40 estimators, Cost: 0.6559072532775955
# Epoch 4, After 41 estimators, Cost: 0.12157176321223809
# Epoch 4, After 42 estimators, Cost: 4.029509637476933
# Epoch 4, After 43 estimators, Cost: 0.012442352878423069
# Epoch 4, After 44 estimators, Cost: 0.09143210655870977
# Epoch 4, After 45 estimators, Cost: 1.920465818944016
# Epoch 4, After 46 estimators, Cost: 0.0001104004351609411
# Epoch 4, After 47 estimators, Cost: 3.1989374507816573
# Epoch 4, After 48 estimators, Cost: 4.425115630088517
# Epoch 4, After 49 estimators, Cost: 0.02030061011042018
# Epoch 4, After 50 estimators, Cost: 0.04573505415366561
# Epoch 4, After 51 estimators, Cost: 0.32387993071202764
# Epoch 4, After 52 estimators, Cost: 0.02246963868527669
# Epoch 4, After 53 estimators, Cost: 1.6938510958294255
# Epoch 4, After 54 estimators, Cost: 0.22446292397825807
# Epoch 4, After 55 estimators, Cost: 3.909955669661267
# Epoch 4, After 56 estimators, Cost: 0.3088393155360537
# Epoch 4, After 57 estimators, Cost: 0.007530232262154825
# Epoch 4, After 58 estimators, Cost: 0.004736527886579839
# Epoch 4, After 59 estimators, Cost: 1.7940561958934114
# Epoch 4, After 60 estimators, Cost: 1.7585134775706024
# Epoch 4, After 61 estimators, Cost: 3.0066392394497212
# Epoch 4, After 62 estimators, Cost: 2.5276495847685075e-05
# Epoch 4, After 63 estimators, Cost: 6.13130860677813
# Epoch 4, After 64 estimators, Cost: 0.4244384576515319
# Epoch 4, After 65 estimators, Cost: 13.482872249045903
# Epoch 4, After 66 estimators, Cost: 1.3128117297347581
# Epoch 4, After 67 estimators, Cost: 0.7828259144387988
# Epoch 4, After 68 estimators, Cost: 0.66451031592348
# Epoch 4, After 69 estimators, Cost: 0.24633631017328841
# Epoch 4, After 70 estimators, Cost: 0.02449153134959044
# Epoch 4, After 71 estimators, Cost: 2.075731272180491
# Epoch 4, After 72 estimators, Cost: 0.19396285924560944
# Epoch 4, After 73 estimators, Cost: 0.004868047819912771
# Epoch 4, After 74 estimators, Cost: 0.07637747460197629
# Epoch 4, After 75 estimators, Cost: 1.0062746501057729
# Epoch 4, After 76 estimators, Cost: 1.2251409555991914e-05
# Epoch 4, After 77 estimators, Cost: 1.3333541709288097
# Epoch 4, After 78 estimators, Cost: 1.5003947053824116
# Epoch 4, After 79 estimators, Cost: 0.6469449430283943
# Epoch 4, After 80 estimators, Cost: 0.04095777395297315
# Epoch 4, After 81 estimators, Cost: 1.5042171997157505
# Epoch 4, After 82 estimators, Cost: 0.008681452613683392
# Epoch 4, After 83 estimators, Cost: 0.13810696632833444
# Epoch 4, After 84 estimators, Cost: 1.015324445741424
# Epoch 4, After 85 estimators, Cost: 0.030998503751452015
# Epoch 4, After 86 estimators, Cost: 0.6998106466260393
# Epoch 4, After 87 estimators, Cost: 1.6582236348071149
# Epoch 4, After 88 estimators, Cost: 0.3510460646819783
# Epoch 4, After 89 estimators, Cost: 4.1593259347951035
# Epoch 4, After 90 estimators, Cost: 0.9620123993122972
# Epoch 4, After 91 estimators, Cost: 0.3716124533273835
# Epoch 4, After 92 estimators, Cost: 0.4423692348744839
# Epoch 4, After 93 estimators, Cost: 1.8096710761474835
# Epoch 4, After 94 estimators, Cost: 0.2464975028525431
# Epoch 4, After 95 estimators, Cost: 22.887643057288816
# Epoch 4, After 96 estimators, Cost: 2.021577116888216
# Epoch 4, After 97 estimators, Cost: 4.436996028179455
# Epoch 4, After 98 estimators, Cost: 0.6823707459331458
# Epoch 4, After 99 estimators, Cost: 0.9026313050304695
# Epoch 4, After 100 estimators, Cost: 0.20320997842779723
# Epoch 4, After 101 estimators, Cost: 1.4823218182736755
# Epoch 4, After 102 estimators, Cost: 0.02261998999675641
# Epoch 4, After 103 estimators, Cost: 0.36252601879924234
# Epoch 4, After 104 estimators, Cost: 3.7021352739650664
# Epoch 4, After 105 estimators, Cost: 0.7961899773892049
# Epoch 4, After 106 estimators, Cost: 10.858691552176671
# Epoch 4, After 107 estimators, Cost: 3.2493132297327683
# Epoch 4, After 108 estimators, Cost: 2.094509647982163
# Epoch 4, After 109 estimators, Cost: 1.8864868015593008
# Epoch 4, After 110 estimators, Cost: 0.1701392518357899
# Epoch 4, After 111 estimators, Cost: 2.7723437364761043
# Epoch 4, After 112 estimators, Cost: 0.39903687042347946
# Epoch 4, After 113 estimators, Cost: 0.8595654594355612
# Epoch 4, After 114 estimators, Cost: 0.007985330247711786
# Epoch 4, After 115 estimators, Cost: 0.48446882493155496
# Epoch 4, After 116 estimators, Cost: 0.31247046083647895
# Epoch 4, After 117 estimators, Cost: 0.766187396123776
# Epoch 4, After 118 estimators, Cost: 0.013509693684347358
# Epoch 4, After 119 estimators, Cost: 0.0834192523406809
# Epoch 4, After 120 estimators, Cost: 5.695291553480026
# Epoch 4, After 121 estimators, Cost: 0.000293162019519913
# Epoch 4, After 122 estimators, Cost: 1.230626822456088
# Epoch 4, After 123 estimators, Cost: 0.3010527309328805
# Epoch 4, After 124 estimators, Cost: 0.007279365534635208
# Epoch 4, After 125 estimators, Cost: 3.3287850115097912
# Epoch 4, After 126 estimators, Cost: 0.9845254835100128
# Epoch 4, After 127 estimators, Cost: 0.14625610446410459
# Epoch 4, After 128 estimators, Cost: 0.19056571851896295
# Epoch 4, After 129 estimators, Cost: 3.233042772729718
# Epoch 4, After 130 estimators, Cost: 0.05098700680408713
# Epoch 4, After 131 estimators, Cost: 0.15749416412964995
# Epoch 4, After 132 estimators, Cost: 0.004358632704305257
# Epoch 4, After 133 estimators, Cost: 0.07836248467411208
# Epoch 4, After 134 estimators, Cost: 0.988468616184175
# Epoch 4, After 135 estimators, Cost: 1.7423153356929413
# Epoch 4, After 136 estimators, Cost: 0.15711267712664587
# Epoch 4, After 137 estimators, Cost: 1.5230191547482732
# Epoch 4, After 138 estimators, Cost: 9.4096645952939
# Epoch 4, After 139 estimators, Cost: 0.30797438462419313
# Epoch 4, After 140 estimators, Cost: 7.70449846584394
# Epoch 4, After 141 estimators, Cost: 0.0997199856336517
# Epoch 4, After 142 estimators, Cost: 5.120626354369719
# Epoch 4, After 143 estimators, Cost: 0.02833527074368168
# Epoch 4, After 144 estimators, Cost: 1.678628151075499
# Epoch 4, After 145 estimators, Cost: 0.9264307338069571
# Epoch 4, After 146 estimators, Cost: 0.0027099419542078707
# Epoch 4, After 147 estimators, Cost: 0.8370473810629114
# Epoch 4, After 148 estimators, Cost: 9.168382919016823
# Epoch 4, After 149 estimators, Cost: 0.032055847289829346
# Epoch 5, After 0 estimators, Cost: 0.5811213365609046
# Epoch 5, After 1 estimators, Cost: 0.10201314002154542
# Epoch 5, After 2 estimators, Cost: 0.3628877956063697
# Epoch 5, After 3 estimators, Cost: 0.09340638036171448
# Epoch 5, After 4 estimators, Cost: 2.9775604368130786
# Epoch 5, After 5 estimators, Cost: 1.7498686763031774
# Epoch 5, After 6 estimators, Cost: 1.0623713025815318
# Epoch 5, After 7 estimators, Cost: 0.7182504933648169
# Epoch 5, After 8 estimators, Cost: 5.285454399531373
# Epoch 5, After 9 estimators, Cost: 0.5919036605390843
# Epoch 5, After 10 estimators, Cost: 0.4797884508749975
# Epoch 5, After 11 estimators, Cost: 3.56668055041636
# Epoch 5, After 12 estimators, Cost: 1.554213066947096
# Epoch 5, After 13 estimators, Cost: 0.01355867698168355
# Epoch 5, After 14 estimators, Cost: 0.4887577349953355
# Epoch 5, After 15 estimators, Cost: 0.009422420008423582
# Epoch 5, After 16 estimators, Cost: 0.47270752643568315
# Epoch 5, After 17 estimators, Cost: 0.925413941753204
# Epoch 5, After 18 estimators, Cost: 0.013035867213592005
# Epoch 5, After 19 estimators, Cost: 1.7342380951317689
# Epoch 5, After 20 estimators, Cost: 0.03574652715065747
# Epoch 5, After 21 estimators, Cost: 4.030510788342659
# Epoch 5, After 22 estimators, Cost: 0.002862028400592694
# Epoch 5, After 23 estimators, Cost: 0.3623705244558129
# Epoch 5, After 24 estimators, Cost: 3.0625186196317995
# Epoch 5, After 25 estimators, Cost: 1.2746471066119556
# Epoch 5, After 26 estimators, Cost: 0.7453416902233573
# Epoch 5, After 27 estimators, Cost: 4.9160324008578415
# Epoch 5, After 28 estimators, Cost: 0.6882139938278131
# Epoch 5, After 29 estimators, Cost: 0.07114712077065481
# Epoch 5, After 30 estimators, Cost: 1.0410643061085267
# Epoch 5, After 31 estimators, Cost: 1.7477774941114264
# Epoch 5, After 32 estimators, Cost: 1.2191393155741979
# Epoch 5, After 33 estimators, Cost: 3.9869885012471857
# Epoch 5, After 34 estimators, Cost: 0.34142386571459205
# Epoch 5, After 35 estimators, Cost: 0.5057899831757167
# Epoch 5, After 36 estimators, Cost: 1.2059861606207216
# Epoch 5, After 37 estimators, Cost: 0.4597540110165317
# Epoch 5, After 38 estimators, Cost: 0.00022303500288130648
# Epoch 5, After 39 estimators, Cost: 1.3946331164586883
# Epoch 5, After 40 estimators, Cost: 0.48641936678408104
# Epoch 5, After 41 estimators, Cost: 0.04710016546951302
# Epoch 5, After 42 estimators, Cost: 3.709532657072188
# Epoch 5, After 43 estimators, Cost: 0.027194347551412475
# Epoch 5, After 44 estimators, Cost: 0.19391551158254888
# Epoch 5, After 45 estimators, Cost: 1.6842484481415054
# Epoch 5, After 46 estimators, Cost: 0.017283568876425962
# Epoch 5, After 47 estimators, Cost: 2.764537731960021
# Epoch 5, After 48 estimators, Cost: 3.9391957778031266
# Epoch 5, After 49 estimators, Cost: 0.07132067868692912
# Epoch 5, After 50 estimators, Cost: 0.01167123485237299
# Epoch 5, After 51 estimators, Cost: 0.2698601829797863
# Epoch 5, After 52 estimators, Cost: 0.010258892197228302
# Epoch 5, After 53 estimators, Cost: 1.7057592459154
# Epoch 5, After 54 estimators, Cost: 0.12954831957763466
# Epoch 5, After 55 estimators, Cost: 3.803520617684455
# Epoch 5, After 56 estimators, Cost: 0.4357796147383159
# Epoch 5, After 57 estimators, Cost: 0.045952667786985694
# Epoch 5, After 58 estimators, Cost: 0.0003761851720394343
# Epoch 5, After 59 estimators, Cost: 1.4364639299222077
# Epoch 5, After 60 estimators, Cost: 1.4042729441234372
# Epoch 5, After 61 estimators, Cost: 2.551931926363808
# Epoch 5, After 62 estimators, Cost: 0.000257827438124299
# Epoch 5, After 63 estimators, Cost: 5.453987289925962
# Epoch 5, After 64 estimators, Cost: 0.2649155851154907
# Epoch 5, After 65 estimators, Cost: 12.603614526271631
# Epoch 5, After 66 estimators, Cost: 1.068637907884179
# Epoch 5, After 67 estimators, Cost: 0.826467647446032
# Epoch 5, After 68 estimators, Cost: 0.8201523501249421
# Epoch 5, After 69 estimators, Cost: 0.15332908147301322
# Epoch 5, After 70 estimators, Cost: 0.009578353653261606
# Epoch 5, After 71 estimators, Cost: 1.7323504632729243
# Epoch 5, After 72 estimators, Cost: 0.13837883972847406
# Epoch 5, After 73 estimators, Cost: 0.0017855580117736728
# Epoch 5, After 74 estimators, Cost: 0.12175872922039623
# Epoch 5, After 75 estimators, Cost: 1.1272157286889
# Epoch 5, After 76 estimators, Cost: 0.0013660905783783716
# Epoch 5, After 77 estimators, Cost: 1.1412625152438254
# Epoch 5, After 78 estimators, Cost: 1.1798715261128532
# Epoch 5, After 79 estimators, Cost: 0.8163232927109262
# Epoch 5, After 80 estimators, Cost: 0.054534832680656814
# Epoch 5, After 81 estimators, Cost: 1.281895699954335
# Epoch 5, After 82 estimators, Cost: 0.0019668527772691
# Epoch 5, After 83 estimators, Cost: 0.08562332039300685
# Epoch 5, After 84 estimators, Cost: 0.7597349910979295
# Epoch 5, After 85 estimators, Cost: 0.09773245017685389
# Epoch 5, After 86 estimators, Cost: 0.6278454624292473
# Epoch 5, After 87 estimators, Cost: 1.452150502441534
# Epoch 5, After 88 estimators, Cost: 0.4333979113019343
# Epoch 5, After 89 estimators, Cost: 3.6506592473505965
# Epoch 5, After 90 estimators, Cost: 1.1632377867486645
# Epoch 5, After 91 estimators, Cost: 0.43650435390975156
# Epoch 5, After 92 estimators, Cost: 0.4132105853858823
# Epoch 5, After 93 estimators, Cost: 1.5339345323460272
# Epoch 5, After 94 estimators, Cost: 0.23633800049610829
# Epoch 5, After 95 estimators, Cost: 21.734687651343158
# Epoch 5, After 96 estimators, Cost: 1.7084131169718582
# Epoch 5, After 97 estimators, Cost: 3.90086545830567
# Epoch 5, After 98 estimators, Cost: 0.5960683351043401
# Epoch 5, After 99 estimators, Cost: 0.7419085457114363
# Epoch 5, After 100 estimators, Cost: 0.25440916642963635
# Epoch 5, After 101 estimators, Cost: 1.3133185276326278
# Epoch 5, After 102 estimators, Cost: 0.00028506747284102546
# Epoch 5, After 103 estimators, Cost: 0.2375112308195094
# Epoch 5, After 104 estimators, Cost: 3.2556399739874213
# Epoch 5, After 105 estimators, Cost: 0.5870554958910749
# Epoch 5, After 106 estimators, Cost: 10.003685908932962
# Epoch 5, After 107 estimators, Cost: 3.3198652764788785
# Epoch 5, After 108 estimators, Cost: 1.7563969694205916
# Epoch 5, After 109 estimators, Cost: 2.100451063312831
# Epoch 5, After 110 estimators, Cost: 0.07970378504418305
# Epoch 5, After 111 estimators, Cost: 2.435998258129486
# Epoch 5, After 112 estimators, Cost: 0.2682266380119199
# Epoch 5, After 113 estimators, Cost: 0.8715212851510741
# Epoch 5, After 114 estimators, Cost: 6.450623675347884e-06
# ...
# Epoch 8, After 13 estimators, Cost: 0.025589918627925857
# Epoch 8, After 14 estimators, Cost: 0.1967480037473255
# Epoch 8, After 15 estimators, Cost: 0.02506148612023186
# Epoch 8, After 16 estimators, Cost: 1.0083270021224922
# Epoch 8, After 17 estimators, Cost: 0.4232801124475384
# Epoch 8, After 18 estimators, Cost: 0.19790063808064204
# Epoch 8, After 19 estimators, Cost: 1.0131192217861547
# Epoch 8, After 20 estimators, Cost: 0.2023318750538444
# Epoch 8, After 21 estimators, Cost: 3.2118465008527086
# Epoch 8, After 22 estimators, Cost: 0.06530783320519454
# Epoch 8, After 23 estimators, Cost: 0.07595489767367991
# Epoch 8, After 24 estimators, Cost: 2.0378999310585737
# Epoch 8, After 25 estimators, Cost: 1.444008927498044
# Epoch 8, After 26 estimators, Cost: 0.36602146442676725
# Epoch 8, After 27 estimators, Cost: 3.668314351458905
# Epoch 8, After 28 estimators, Cost: 1.177970125512108
# Epoch 8, After 29 estimators, Cost: 0.026079635537723276
# Epoch 8, After 30 estimators, Cost: 0.6116362099651967
# Epoch 8, After 31 estimators, Cost: 1.1884411992736377
# Epoch 8, After 32 estimators, Cost: 1.5005430098440387
# Epoch 8, After 33 estimators, Cost: 2.940766605943758
# Epoch 8, After 34 estimators, Cost: 0.6143392841280086
# Epoch 8, After 35 estimators, Cost: 0.3686370745423042
# Epoch 8, After 36 estimators, Cost: 0.6229297411070989
# Epoch 8, After 37 estimators, Cost: 0.2516188390058746
# Epoch 8, After 38 estimators, Cost: 0.051079224491398366
# Epoch 8, After 39 estimators, Cost: 0.7371521185779346
# Epoch 8, After 40 estimators, Cost: 0.25373576138819526
# Epoch 8, After 41 estimators, Cost: 0.008605450164753815
# Epoch 8, After 42 estimators, Cost: 3.34730329483797
# Epoch 8, After 43 estimators, Cost: 0.07492273625626353
# Epoch 8, After 44 estimators, Cost: 0.5295480483702516
# Epoch 8, After 45 estimators, Cost: 1.161532287198747
# Epoch 8, After 46 estimators, Cost: 0.19232033023042305
# Epoch 8, After 47 estimators, Cost: 1.8606631763537227
# Epoch 8, After 48 estimators, Cost: 2.890483808316245
# Epoch 8, After 49 estimators, Cost: 0.2567862576102972
# Epoch 8, After 50 estimators, Cost: 0.018052702997616216
# Epoch 8, After 51 estimators, Cost: 0.15167660312313602
# Epoch 8, After 52 estimators, Cost: 9.468828568685568e-05
# Epoch 8, After 53 estimators, Cost: 1.7190039912715276
# Epoch 8, After 54 estimators, Cost: 0.007207103249410598
# Epoch 8, After 55 estimators, Cost: 3.5638335322225743
# Epoch 8, After 56 estimators, Cost: 0.6840494988211991
# Epoch 8, After 57 estimators, Cost: 0.21547088234925008
# Epoch 8, After 58 estimators, Cost: 0.018944548327445538
# Epoch 8, After 59 estimators, Cost: 0.7938229392390853
# Epoch 8, After 60 estimators, Cost: 0.7514984133107235
# Epoch 8, After 61 estimators, Cost: 1.7162255645458224
# Epoch 8, After 62 estimators, Cost: 0.0064322014696550885
# Epoch 8, After 63 estimators, Cost: 4.091772231737933
# Epoch 8, After 64 estimators, Cost: 0.050468812556923245
# Epoch 8, After 65 estimators, Cost: 10.625043991606855
# Epoch 8, After 66 estimators, Cost: 0.6926346778509581
# Epoch 8, After 67 estimators, Cost: 0.9603218948342602
# Epoch 8, After 68 estimators, Cost: 1.0806493688613998
# Epoch 8, After 69 estimators, Cost: 0.02278045106679355
# Epoch 8, After 70 estimators, Cost: 0.002808492535205817
# Epoch 8, After 71 estimators, Cost: 1.147216638222973
# Epoch 8, After 72 estimators, Cost: 0.09495570332666613
# Epoch 8, After 73 estimators, Cost: 0.0015107925627821153
# Epoch 8, After 74 estimators, Cost: 0.2838495906229812
# Epoch 8, After 75 estimators, Cost: 1.4693741705946637
# Epoch 8, After 76 estimators, Cost: 0.016241765987271044
# Epoch 8, After 77 estimators, Cost: 0.8868101928615015
# Epoch 8, After 78 estimators, Cost: 0.6050776343441338
# Epoch 8, After 79 estimators, Cost: 1.1489280057812181
# Epoch 8, After 80 estimators, Cost: 0.08648787343501523
# Epoch 8, After 81 estimators, Cost: 0.8136809138107467
# Epoch 8, After 82 estimators, Cost: 0.11959862825314371
# Epoch 8, After 83 estimators, Cost: 0.033965266581606805
# Epoch 8, After 84 estimators, Cost: 0.33258074078648714
# Epoch 8, After 85 estimators, Cost: 0.37354779547992717
# Epoch 8, After 86 estimators, Cost: 0.455840797322489
# Epoch 8, After 87 estimators, Cost: 1.0023555795981598
# Epoch 8, After 88 estimators, Cost: 0.6462254693768601
# Epoch 8, After 89 estimators, Cost: 2.596295097994609
# Epoch 8, After 90 estimators, Cost: 1.5510507887048233
# Epoch 8, After 91 estimators, Cost: 0.6273431913644228
# Epoch 8, After 92 estimators, Cost: 0.33602359809109067
# Epoch 8, After 93 estimators, Cost: 0.9677226502822581
# Epoch 8, After 94 estimators, Cost: 0.20471231983307503
# Epoch 8, After 95 estimators, Cost: 19.156154134068604
# Epoch 8, After 96 estimators, Cost: 1.0743052207740205
# Epoch 8, After 97 estimators, Cost: 2.8047733756099427
# Epoch 8, After 98 estimators, Cost: 0.5354027529502753
# Epoch 8, After 99 estimators, Cost: 0.5133975779637482
# Epoch 8, After 100 estimators, Cost: 0.3017519318778595
# Epoch 8, After 101 estimators, Cost: 0.9352722321455882
# Epoch 8, After 102 estimators, Cost: 0.07477554502790877
# Epoch 8, After 103 estimators, Cost: 0.04704105570808521
# Epoch 8, After 104 estimators, Cost: 2.3656828644559162
# Epoch 8, After 105 estimators, Cost: 0.25394108883714744
# Epoch 8, After 106 estimators, Cost: 8.190239088978446
# Epoch 8, After 107 estimators, Cost: 3.5367932745180655
# Epoch 8, After 108 estimators, Cost: 1.158528578334994
# Epoch 8, After 109 estimators, Cost: 2.4291583210111716
# Epoch 8, After 110 estimators, Cost: 1.1105738865043722e-05
# Epoch 8, After 111 estimators, Cost: 1.8645503602366482
# Epoch 8, After 112 estimators, Cost: 0.06913947209609421
# Epoch 8, After 113 estimators, Cost: 0.9221322061497327
# Epoch 8, After 114 estimators, Cost: 0.04374725952365519
# Epoch 8, After 115 estimators, Cost: 0.6820146515797552
# Epoch 8, After 116 estimators, Cost: 0.361180195201333
# Epoch 8, After 117 estimators, Cost: 0.29539101162878373
# Epoch 8, After 118 estimators, Cost: 0.0018884087396533803
# Epoch 8, After 119 estimators, Cost: 0.010177611804488838
# Epoch 8, After 120 estimators, Cost: 5.483879229963785
# Epoch 8, After 121 estimators, Cost: 0.017653998565934022
# Epoch 8, After 122 estimators, Cost: 2.3352805066998523
# Epoch 8, After 123 estimators, Cost: 0.0907981993118058
# Epoch 8, After 124 estimators, Cost: 0.07888416656254839
# Epoch 8, After 125 estimators, Cost: 1.9435325771653893
# Epoch 8, After 126 estimators, Cost: 1.0583254282861947
# Epoch 8, After 127 estimators, Cost: 0.10717324671641693
# Epoch 8, After 128 estimators, Cost: 0.12366217809065021
# Epoch 8, After 129 estimators, Cost: 1.9455111688710187
# Epoch 8, After 130 estimators, Cost: 0.4284333675347642
# Epoch 8, After 131 estimators, Cost: 0.0015126202230430297
# Epoch 8, After 132 estimators, Cost: 0.09966035497222266
# Epoch 8, After 133 estimators, Cost: 0.019387167011013097
# Epoch 8, After 134 estimators, Cost: 1.5971289530173367
# Epoch 8, After 135 estimators, Cost: 0.8203324125284454
# Epoch 8, After 136 estimators, Cost: 0.6393582156523732
# Epoch 8, After 137 estimators, Cost: 0.9877521064379867
# Epoch 8, After 138 estimators, Cost: 6.995529265825151
# Epoch 8, After 139 estimators, Cost: 0.06914786977997267
# Epoch 8, After 140 estimators, Cost: 6.959609983210341
# Epoch 8, After 141 estimators, Cost: 0.0038427759554270254
# Epoch 8, After 142 estimators, Cost: 3.39527204208988
# Epoch 8, After 143 estimators, Cost: 0.05448527356248646
# Epoch 8, After 144 estimators, Cost: 0.8138352511870353
# Epoch 8, After 145 estimators, Cost: 0.6439622978230668
# Epoch 8, After 146 estimators, Cost: 0.17108424517542478
# Epoch 8, After 147 estimators, Cost: 0.25470622627964257
# Epoch 8, After 148 estimators, Cost: 10.22323490745147
# Epoch 8, After 149 estimators, Cost: 0.3204909321279633
# Epoch 9, After 0 estimators, Cost: 0.1178490730456742
# Epoch 9, After 1 estimators, Cost: 0.219305665007622
# Epoch 9, After 2 estimators, Cost: 0.1264454509530794
# Epoch 9, After 3 estimators, Cost: 0.437762796425568
# Epoch 9, After 4 estimators, Cost: 2.059225427838304
# Epoch 9, After 5 estimators, Cost: 1.0697213414769589
# Epoch 9, After 6 estimators, Cost: 0.7486567482291188
# Epoch 9, After 7 estimators, Cost: 0.697195532527485
# Epoch 9, After 8 estimators, Cost: 3.823879892942762
# Epoch 9, After 9 estimators, Cost: 0.986271014604268
# Epoch 9, After 10 estimators, Cost: 0.3589047483475074
# Epoch 9, After 11 estimators, Cost: 4.803982875317571
# Epoch 9, After 12 estimators, Cost: 1.785660489429671
# Epoch 9, After 13 estimators, Cost: 0.04904189909690708
# Epoch 9, After 14 estimators, Cost: 0.15110965263789258
# Epoch 9, After 15 estimators, Cost: 0.045463961850530525
# Epoch 9, After 16 estimators, Cost: 1.1655897225356335
# Epoch 9, After 17 estimators, Cost: 0.32547382062804475
# Epoch 9, After 18 estimators, Cost: 0.2786136644115556
# Epoch 9, After 19 estimators, Cost: 0.8707151459901027
# Epoch 9, After 20 estimators, Cost: 0.2686329196484599
# Epoch 9, After 21 estimators, Cost: 3.0604810739189516
# Epoch 9, After 22 estimators, Cost: 0.10805157580382935
# Epoch 9, After 23 estimators, Cost: 0.038231676944850954
# Epoch 9, After 24 estimators, Cost: 1.8118206870412745
# Epoch 9, After 25 estimators, Cost: 1.4959767490457234
# Epoch 9, After 26 estimators, Cost: 0.30081172928091254
# Epoch 9, After 27 estimators, Cost: 3.377561505296369
# Epoch 9, After 28 estimators, Cost: 1.3276721710352701
# Epoch 9, After 29 estimators, Cost: 0.022979075504733673
# Epoch 9, After 30 estimators, Cost: 0.5173608816512834
# Epoch 9, After 31 estimators, Cost: 1.084645010670495
# Epoch 9, After 32 estimators, Cost: 1.5384416451687248
# Epoch 9, After 33 estimators, Cost: 2.7095298040217046
# Epoch 9, After 34 estimators, Cost: 0.6939650282802265
# Epoch 9, After 35 estimators, Cost: 0.33424886314801133
# Epoch 9, After 36 estimators, Cost: 0.5120208847371432
# Epoch 9, After 37 estimators, Cost: 0.22129775154377934
# Epoch 9, After 38 estimators, Cost: 0.07965077842490197
# Epoch 9, After 39 estimators, Cost: 0.6045536524878047
# Epoch 9, After 40 estimators, Cost: 0.21788045286089797
# Epoch 9, After 41 estimators, Cost: 0.02951882118214417
# Epoch 9, After 42 estimators, Cost: 3.318512771129967
# Epoch 9, After 43 estimators, Cost: 0.08912218930697854
# Epoch 9, After 44 estimators, Cost: 0.6311337324171213
# Epoch 9, After 45 estimators, Cost: 1.0390272279922717
# Epoch 9, After 46 estimators, Cost: 0.2622850651472443
# Epoch 9, After 47 estimators, Cost: 1.657491195445137
# Epoch 9, After 48 estimators, Cost: 2.6460280288355973
# Epoch 9, After 49 estimators, Cost: 0.3118995221829754
# Epoch 9, After 50 estimators, Cost: 0.0380407327912401
# Epoch 9, After 51 estimators, Cost: 0.1252789977509362
# Epoch 9, After 52 estimators, Cost: 0.0014034269253865772
# Epoch 9, After 53 estimators, Cost: 1.7197646427061648
# Epoch 9, After 54 estimators, Cost: 0.00018126664211762212
# Epoch 9, After 55 estimators, Cost: 3.5047955648764835
# Epoch 9, After 56 estimators, Cost: 0.732396322841128
# Epoch 9, After 57 estimators, Cost: 0.26941643665821763
# Epoch 9, After 58 estimators, Cost: 0.02312711417110371
# Epoch 9, After 59 estimators, Cost: 0.6670305906204439
# Epoch 9, After 60 estimators, Cost: 0.621186748519611
# Epoch 9, After 61 estimators, Cost: 1.5441885459243567
# Epoch 9, After 62 estimators, Cost: 0.009825911625292932
# Epoch 9, After 63 estimators, Cost: 3.788291129789269
# Epoch 9, After 64 estimators, Cost: 0.02441530828807056
# Epoch 9, After 65 estimators, Cost: 10.14269034255605
# Epoch 9, After 66 estimators, Cost: 0.6269036352712147
# Epoch 9, After 67 estimators, Cost: 1.0008721350290641
# Epoch 9, After 68 estimators, Cost: 1.123210238776457
# Epoch 9, After 69 estimators, Cost: 0.008201663447512761
# Epoch 9, After 70 estimators, Cost: 0.008790975051699536
# Epoch 9, After 71 estimators, Cost: 1.0342741885269202
# Epoch 9, After 72 estimators, Cost: 0.09546077582956325
# Epoch 9, After 73 estimators, Cost: 0.003900210638310175
# Epoch 9, After 74 estimators, Cost: 0.33870104497218634
# Epoch 9, After 75 estimators, Cost: 1.5695013340692157
# Epoch 9, After 76 estimators, Cost: 0.023286147201740118
# Epoch 9, After 77 estimators, Cost: 0.8517809670609331
# Epoch 9, After 78 estimators, Cost: 0.493311122085834
# Epoch 9, After 79 estimators, Cost: 1.217479774407169
# Epoch 9, After 80 estimators, Cost: 0.09443237284108477
# Epoch 9, After 81 estimators, Cost: 0.7086994626445312
# Epoch 9, After 82 estimators, Cost: 0.17544029997991628
# Epoch 9, After 83 estimators, Cost: 0.029010930458171727
# Epoch 9, After 84 estimators, Cost: 0.2559031489607288
# Epoch 9, After 85 estimators, Cost: 0.4669714939698044
# Epoch 9, After 86 estimators, Cost: 0.4133487578444053
# Epoch 9, After 87 estimators, Cost: 0.8977808493312716
# Epoch 9, After 88 estimators, Cost: 0.7045388714483962
# Epoch 9, After 89 estimators, Cost: 2.3579509995424
# Epoch 9, After 90 estimators, Cost: 1.6304403703958983
# Epoch 9, After 91 estimators, Cost: 0.684809608005236
# Epoch 9, After 92 estimators, Cost: 0.31549016377343636
# Epoch 9, After 93 estimators, Cost: 0.8428583192984466
# Epoch 9, After 94 estimators, Cost: 0.19554539508083993
# Epoch 9, After 95 estimators, Cost: 18.52724735902271
# Epoch 9, After 96 estimators, Cost: 0.935777814257025
# Epoch 9, After 97 estimators, Cost: 2.5589369782570377
# Epoch 9, After 98 estimators, Cost: 0.5427149750718928
# Epoch 9, After 99 estimators, Cost: 0.47724599246298827
# Epoch 9, After 100 estimators, Cost: 0.2986449449170731
# Epoch 9, After 101 estimators, Cost: 0.8456136409409544
# Epoch 9, After 102 estimators, Cost: 0.11787614495986264
# Epoch 9, After 103 estimators, Cost: 0.02184606727043948
# Epoch 9, After 104 estimators, Cost: 2.169366995637181
# Epoch 9, After 105 estimators, Cost: 0.1963161470938205
# Epoch 9, After 106 estimators, Cost: 7.766893446883491
# Epoch 9, After 107 estimators, Cost: 3.601780905493858
# Epoch 9, After 108 estimators, Cost: 1.0394381517089466
# Epoch 9, After 109 estimators, Cost: 2.4784020049591917
# Epoch 9, After 110 estimators, Cost: 0.003974439111624489
# Epoch 9, After 111 estimators, Cost: 1.7542375981232918
# Epoch 9, After 112 estimators, Cost: 0.0400575196167073
# Epoch 9, After 113 estimators, Cost: 0.939230685882314
# Epoch 9, After 114 estimators, Cost: 0.06994733211139458
# Epoch 9, After 115 estimators, Cost: 0.7176736472470026
# Epoch 9, After 116 estimators, Cost: 0.3727433687477364
# Epoch 9, After 117 estimators, Cost: 0.2455548391316813
# Epoch 9, After 118 estimators, Cost: 0.005053993427735173
# Epoch 9, After 119 estimators, Cost: 0.029218840108758474
# Epoch 9, After 120 estimators, Cost: 5.438921756939217
# Epoch 9, After 121 estimators, Cost: 0.02541814688373239
# Epoch 9, After 122 estimators, Cost: 2.551719680060464
# Epoch 9, After 123 estimators, Cost: 0.07425685413216755
# Epoch 9, After 124 estimators, Cost: 0.11360564973985628
# Epoch 9, After 125 estimators, Cost: 1.7403881324676127
# Epoch 9, After 126 estimators, Cost: 1.0753001116228669
# Epoch 9, After 127 estimators, Cost: 0.10142955133326637
# Epoch 9, After 128 estimators, Cost: 0.12815795500403898
# Epoch 9, After 129 estimators, Cost: 1.7497338847229127
# Epoch 9, After 130 estimators, Cost: 0.5312647546755206
# Epoch 9, After 131 estimators, Cost: 0.0002483323987364589
# Epoch 9, After 132 estimators, Cost: 0.11979711318017297
# Epoch 9, After 133 estimators, Cost: 0.04385211897379064
# Epoch 9, After 134 estimators, Cost: 1.716288728611017
# Epoch 9, After 135 estimators, Cost: 0.7004468688632005
# Epoch 9, After 136 estimators, Cost: 0.76004358593632
# Epoch 9, After 137 estimators, Cost: 0.8997494832829961
# Epoch 9, After 138 estimators, Cost: 6.621614928620773
# Epoch 9, After 139 estimators, Cost: 0.044563068964734054
# Epoch 9, After 140 estimators, Cost: 6.832277583041872
# Epoch 9, After 141 estimators, Cost: 0.014772903113679028
# Epoch 9, After 142 estimators, Cost: 3.1253259674744727
# Epoch 9, After 143 estimators, Cost: 0.08952331046520465
# Epoch 9, After 144 estimators, Cost: 0.7029386963230363
# Epoch 9, After 145 estimators, Cost: 0.6281540620210149
# Epoch 9, After 146 estimators, Cost: 0.23037496122593593
# Epoch 9, After 147 estimators, Cost: 0.18619560729155005
# Epoch 9, After 148 estimators, Cost: 10.305980435969854
# Epoch 9, After 149 estimators, Cost: 0.395132825714676

# %%
# Load Model's trained Parameters to plot it with the 
W_1 = poly_model.params['W'][:, 0]
W_2 = poly_model.params['W'][:, 1]
b = poly_model.params['b']
X_model = np.linspace(-2, 4, 30).reshape(30, 1) # use X_model to plot the line "naturally" :)

plt.figure(figsize=(20, 8))
plt.plot(X, y, "b.")
plt.plot(X_model, W_1*X_model + W_2*X_model**2 + b, c="r", ls='-', label='Polynomial Model')
plt.plot(X_model, W*X_model + b, c="g", ls='-', label='Linear Model')


plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([-2, 4, -2, 15])
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# # Some things to remember
# - This is called a different name but in general it's not thing different from the Linear one, just need to generate new polynomial features and all done. (If I build the previous Model will e
# - The Previous Model was build wrongly. It run because in that situation, where the dataset has a linear contribution and only 1 feature, but things are often more complicated.
# - I used the learning rate = 0.05, which I think is small, but in reality it really big, my model was diverged, it took me like an hour to figure out, because this learning rate work well with Linear Regression. Set the learning rate to 0.001 worked fine.
